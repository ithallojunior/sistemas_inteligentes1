# %% [markdown]
# # Example of XOR gate using an MLP and MLP class
#
# ## Author: Ithallo Junior Alves Guimarães
#
# #####  Reference:     <http://iamtrask.github.io/2015/07/12/basic-python-network/>

# %%
import numpy as np
import datetime
import sys
sys.path.append("../")
from mlp import mlp

# %% [markdown]
# ## Examples

# %% [markdown]
# #### Using sigmoid

# %%
clf = mlp(seed=1, activation="sigmoid", max_iter=10000, 
          hidden_layer_size=4, alpha=0.1, momentum=0.9,tol=1e-3, weight_range=(-1,1), bias=True)
# %time clf.example_run(show="static")
# Out:
# Stopping by error at 3110
# Results:
#
#  X    y    Predicted
# [0 0] 0 0.0188313853017
# [0 1] 1 0.973142239023
# [1 0] 1 0.986495413493
# [1 1] 0 0.0272136309947
#
# score: 99.900%
# CPU times: user 675 ms, sys: 85.5 ms, total: 760 ms
# Wall time: 849 ms

# %% [markdown]
# #### Using tanh

# %%
clf = mlp(seed=1, activation="tanh", max_iter=10000, 
          hidden_layer_size=4, alpha=0.1, momentum=0.9, tol=1e-3, weight_range=(-1,1), bias=True)
# %time clf.example_run(show="static")
# Out:
# Stopping by error at 43
# Results:
#
#  X    y    Predicted
# [0 0] 0 -0.0185937265671
# [0 1] 1 0.974038657679
# [1 0] 1 0.969530247836
# [1 1] 0 0.0076457703812
#
# score: 99.900%
# CPU times: user 207 ms, sys: 12.4 ms, total: 219 ms
# Wall time: 216 ms

# %% [markdown]
# #### Using softplus

# %%
clf = mlp(seed=1, activation="softplus", max_iter=10000, 
          hidden_layer_size=4, alpha=0.1, momentum=0.9, tol=1e-3, weight_range=(-1,1), bias=True)
# %time clf.example_run(show="static")
# Out:
# Stopping by error at 286
# Results:
#
#  X    y    Predicted
# [0 0] 0 0.0223251858733
# [0 1] 1 0.998906568403
# [1 0] 1 0.999130433731
# [1 1] 0 0.0385154192679
#
# score: 99.901%
# CPU times: user 206 ms, sys: 9.36 ms, total: 215 ms
# Wall time: 213 ms

# %% [markdown]
# #### Using linear (it doesn't work, and it shouldn't)

# %%
clf = mlp(seed=1, activation="linear", max_iter=10000, 
          hidden_layer_size=4, alpha=0.1, momentum=0.1, tol=1e-3, weight_range=(-1,1), bias=True)
# %time clf.example_run(show="static")
# Out:
# Results:
#
#  X    y    Predicted
# [0 0] 0 0.5
# [0 1] 1 0.5
# [1 0] 1 0.5
# [1 1] 0 0.5
#
# score: 50.000%
# CPU times: user 585 ms, sys: 9.54 ms, total: 595 ms
# Wall time: 596 ms
